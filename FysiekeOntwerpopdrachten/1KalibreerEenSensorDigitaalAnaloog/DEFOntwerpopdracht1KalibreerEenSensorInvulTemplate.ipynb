# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 08        |         |
# | :----------------|:--------|
# | Arjun Avhale     | 6542786 |
# | Luc van der Wilt | 6430589 |
# | Thijn Holswilder | 6536387 |
#
# | Planning Groep: 08                                 | Tijdstip / Tijdspanne |
# | -------------------------------------------------- | --------------------- |
# | Brainstormen (3 ideeën per sensor p.p.)            | 11:15 – 11:30         |
# | Mijlpaal 1: Keuze toepassing + criteria definitief | 11:30 – 11:45         |
# | Ontwerp uitwerken (schema + meetplan)              | 11:45 – 12:30         |
# | Pauze 1                                            | 12:30 – 13:45         |
# | Bouw schakeling + code schrijven                   | 13:45 – 14:00         |
# | Eerste kalibratiemeting (30 °C en 50 °C)           | 14:00 – 14:45         |
# | 10 meetpunten verzamelen (temperatuur vs bits)     | 14:45 – 15:30         |
# | Mijlpaal 2: Curve fit + grenswaarden bepalen       | 15:30 – 16:15         |
# | Evaluatie: voldoet aan criteria? + optimaliseren   | 16:15 – 16:50         |
# | Feedback aan elkaar                                | 16:50 – 17:00         |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](schetsen_Thijn_18_02_2026.jpeg "schets Thijn")
#
# ![Alt](schetsen_Arjun_18_02_2026.jpeg "schets Arjun")
#
# ![Alt](schetsen_Luc_18_02_2026.jpeg "schets Luc")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor                          | Toepassing                                                          | Criteria                                                                                                  |
# | :------------------------------ | :------------------------------------------------------------------ | :-------------------------------------------------------------------------------------------------------- |
# | **Druk/krachtsensor**           | Gewicht indiceren met LED-kleuren                                   | 0–10 g (±1 g): groen. 10–20 g (±1 g): geel. 20–30 g (±1 g): rood.                                         |
# | Druk/krachtsensor               | Reactietijd meten bij indrukken na lichtsignaal                     | Tijdsverschil tussen aangaan LED en indrukken sensor meetbaar met milliseconde-resolutie via Arduino.     |
# | Druk/krachtsensor               | Gebruik als eenvoudige weegschaal                                   | Meetbereik minimaal 0–30 g met maximale afwijking van ±1 g.                                               |
# | Druk/krachtsensor               | Bezettingsdetectie stoel                                            | Duidelijk onderscheid tussen geen belasting en belasting boven ingestelde drempelwaarde.                  |
# | **Temperatuursensor (NTC/PTC)** | Temperatuurindicatie met LED-kleuren                                | < 30 °C (±1 °C): groen. 30–50 °C (±1 °C): geel. ≥ 50 °C (±1 °C): rood.                                    |
# | Temperatuursensor               | Koelkastalarm bij grensoverschrijding                               | Betrouwbare detectie van ingestelde minimum- en maximumtemperatuur met alarmactivatie bij overschrijding. |
# | **Lichtsensor (LDR)**           | Lichtintensiteit meten vóór en na doorgang door materiaal/vloeistof | Meetnauwkeurigheid minimaal 2 lux.                                                                        |
# | Lichtsensor (LDR)               | Automatisch inschakelen lantaarnpaal bij weinig licht               | Onder ingestelde lux-drempel moet een schakelsignaal worden gegenereerd.                                  |
# | Lichtsensor (LDR)               | Wekker activeren bij toenemende lichtsterkte                        | Boven ingestelde lux-drempel moet een signaal worden gegenereerd.                                         |
#
# Groep 08 heeft gekozen voor sensor temperatuur.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is.
# ![Alt](schetsen_opstelling_18_02_2026.jpeg "schets Thijn")
# - Je ziet dat de laptop de grafiek van de bitwaarde afleest van de arduino.
# - Je ziet dat de arduino via de breadboard de Temperatuursensor op een theemok zit.
# - Je ziet dat er lampjes op de breadboord zitten die gaan branden bij varieërende temperaturen.
# - Je ziet een temperatuurmeter die de temperatuur van de theemok meet.

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# Opdracht 4
# 1. Welke variabelen ga je veranderen?
# - Temperatuur is de onafhankelijke variabele. De afhankelijke variabele is het aantal bits dat wordt uitgelezen om de LED’s te laten branden.
#
# 2. Over welk bereik ga je deze variabelen veranderen?
# - Het temperatuurbereik ligt tussen 10 °C en 70 °C.
#
# 3. Wat ga je allemaal meten?
# - We laten de verwarmde stof afkoelen en lezen bij elke temperatuurlimiet de bits uit via de grafische plotter. Voor dit experiment gebruiken we de volgende grenzen: boven 40 °C brandt de rode LED, tussen 30 °C en 40 °C de gele LED, en onder 30 °C de groene LED. Na kalibratie en aanpassing van de code plotten we meer dan 10 meetpunten tussen 18 °C en 60 °C.
#
# 4. Hoeveel metingen ga je doen?
# - Eerst voeren we twee metingen uit om het aantal bits bij 40 °C en 30 °C te bepalen. Daarna doen we meer dan 10 metingen voor temperatuur tegen bits om de onzekerheid te verkleinen en een kalibratiecurve te maken.
#
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
# - Ja. We kunnen beoordelen of de temperatuursensor de gekozen temperatuurlimieten betrouwbaar kan meten en correct kan worden gekalibreerd.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#
# ![Alt](Opstelling_rood_18_2_2026.jpeg "meetopstelling rood")
# - Je ziet dat de arduino via de breadboard de Temperatuursensor op een theemok zit.
# - Je ziet dat er lampjes op de breadboord zitten die gaan branden bij varieërende temperaturen.
# - Je ziet een temperatuurmeter die de temperatuur van de theemok meet.

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

Temp = np.array([59, 56 ,52 ,49 ,47 ,45 ,43 ,41 ,39 ,37, 35, 33, 31, 29, 27, 25, 23, 21, 19])
bits = np.array([780 ,768 ,720 ,710 ,685 ,670 ,655 ,644 ,624 ,612, 596, 575, 560, 545, 530, 515, 494, 476, 459])

# %%
def f(x, a, b):
    return a * x + b

# curve fit
popt, pcov = curve_fit(f, Temp, bits)

a_fit, b_fit = popt

print("a =", a_fit)
print("b =", b_fit)

# plot
plt.figure()
plt.scatter(Temp, bits)
plt.plot(Temp, f(Temp, a_fit, b_fit))
plt.xlabel('Temperatuur [$C$]')
plt.ylabel('Bits [$-$]')
plt.show()

bits_30C = f(30, a_fit, b_fit)
bits_40C = f(40, a_fit, b_fit)
Temp_minC = (0-b_fit)/a_fit
Temp_maxC = (1023-b_fit)/a_fit

print(f'aantal bits nodig voor 30 °C: {bits_30C:.0f}')
print(f'aantal bits nodig voor 40 °C: {bits_40C:.0f}')
print(f'de range van de temperatuursensor is: {Temp_minC:.0f} °C tot {Temp_maxC:.0f} °C ')
# Out:
# a = 8.036239305669074
# b = 310.74915019382473
# aantal bits nodig voor 30 °C: 552
# aantal bits nodig voor 40 °C: 632
# de range van de temperatuursensor is: -39 °C tot 89 °C

# %% [markdown]
# ## Boven 40 °C
# ![Alt](Opstelling_rood_18_2_2026.jpeg "meetopstelling rood")
# ## Tussen 30 °C en 40 °C
# ![Alt](Opstelling_geel_18_2_2026.jpeg "meetopstelling geel")
# ## Onder 30 °C
# ![Alt](Opstelling_groen_18_2_2026.jpeg "meetopstelling groen")

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# Er zijn genoeg gegevens verzamelt waardoor we het verband tussen de hoeveelheid bits en temperatuur kunnen bepalen. Er zijn namelijk 19 punten gemeten. Uit de meetpunten blijkt een lineair verband en dat was ook de verwachting. De bits fluctueerde echter wel veel wat maakt dat de onzekerheid wel relatief hoog is, namelijk +/- 20 bits. Wij denken dat dit door meer metingen dan dat we nu gedaan hebben niet voor veel verbetering zal zorgen. Daarnaast konden we door middel van het testen van het product zien dat de rode, gele en groene lampjes bij de juiste temperaturen gingen branden. Dus er hoeven geen extra metingen gedaan te worden aangezien er genoeg metingen verzameld zijn.

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Bruikbaarheid sensor gekozen toepassing:
# We hebben door middel van de meetpunten een verband kunnen bepalen tussen de temperatuur en de bits. Uit de functie fit bleek een lineair verband. Aan de hand van deze fit konden we +/- 1 graden Celsius nauwkeurig bepalen wat die bij die specifieke bits hoorde. Zo hebben we in de Arduino code verwerkt waardoor het lampje groene lampje onder de 30 graden Celsius ging branden, vanaf 30 tot 40 graden het gele lampje en boven de 40 graden ging het rode lampje branden. Je kunt de sensor dus gebruiken om te ongeveer te bepalen hoe warm iets is. Je weet echter alleen of het lager dan 30, tussen 30 en 40 of hoger dan 40 graden is.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor                          | Toepassing                                                          | Criteria                                                                                                  |
# | :------------------------------ | :------------------------------------------------------------------ | :-------------------------------------------------------------------------------------------------------- |
# | **Druk/krachtsensor**           | Gewicht indiceren met LED-kleuren                                   | 0–10 g (±1 g): groen. 10–20 g (±1 g): geel. 20–30 g (±1 g): rood.                                         |
# | Druk/krachtsensor               | Reactietijd meten bij indrukken na lichtsignaal                     | Tijdsverschil tussen aangaan LED en indrukken sensor meetbaar met milliseconde-resolutie via Arduino.     |
# | Druk/krachtsensor               | Gebruik als eenvoudige weegschaal                                   | Meetbereik minimaal 0–30 g met maximale afwijking van ±1 g.                                               |
# | Druk/krachtsensor               | Bezettingsdetectie stoel                                            | Duidelijk onderscheid tussen geen belasting en belasting boven ingestelde drempelwaarde.                  |
# | **Temperatuursensor (NTC/PTC)** | Temperatuurindicatie met LED-kleuren                                | < 30 °C (±1 °C): groen. 30–50 °C (±1 °C): geel. ≥ 50 °C (±1 °C): rood.                                    |
# | Temperatuursensor               | Koelkastalarm bij grensoverschrijding                               | Betrouwbare detectie van ingestelde minimum- en maximumtemperatuur met alarmactivatie bij overschrijding. |
# | **Lichtsensor (LDR)**           | Lichtintensiteit meten vóór en na doorgang door materiaal/vloeistof | Meetnauwkeurigheid minimaal 2 lux.                                                                        |
# | Lichtsensor (LDR)               | Automatisch inschakelen lantaarnpaal bij weinig licht               | Onder ingestelde lux-drempel moet een schakelsignaal worden gegenereerd.                                  |
# | Lichtsensor (LDR)               | Wekker activeren bij toenemende lichtsterkte                        | Boven ingestelde lux-drempel moet een signaal worden gegenereerd.                                         |
#
# Groep 08 heeft gekozen voor sensor temperatuur.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#
# ![Alt](Opstelling_rood_18_2_2026.jpeg "meetopstelling rood")
# - Je ziet dat de arduino via de breadboard de Temperatuursensor op een theemok zit.
# - Je ziet dat er lampjes op de breadboord zitten die gaan branden bij varieërende temperaturen.
# - Je ziet een temperatuurmeter die de temperatuur van de theemok meet.

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

Temp = np.array([59, 56 ,52 ,49 ,47 ,45 ,43 ,41 ,39 ,37, 35, 33, 31, 29, 27, 25, 23, 21, 19])
bits = np.array([780 ,768 ,720 ,710 ,685 ,670 ,655 ,644 ,624 ,612, 596, 575, 560, 545, 530, 515, 494, 476, 459])

# %%
def f(x, a, b):
    return a * x + b

# curve fit
popt, pcov = curve_fit(f, Temp, bits)

a_fit, b_fit = popt

print("a =", a_fit)
print("b =", b_fit)

# plot
plt.figure()
plt.scatter(Temp, bits)
plt.plot(Temp, f(Temp, a_fit, b_fit))
plt.xlabel('Temperatuur [$C$]')
plt.ylabel('Bits [$-$]')
plt.show()

bits_30C = f(30, a_fit, b_fit)
bits_40C = f(40, a_fit, b_fit)
Temp_minC = (0-b_fit)/a_fit
Temp_maxC = (1023-b_fit)/a_fit

print(f'aantal bits nodig voor 30 °C: {bits_30C:.0f}')
print(f'aantal bits nodig voor 40 °C: {bits_40C:.0f}')
print(f'de range van de temperatuursensor is: {Temp_minC:.0f} °C tot {Temp_maxC:.0f} °C ')
# Out:
# a = 8.036239305669074
# b = 310.74915019382473
# aantal bits nodig voor 30 °C: 552
# aantal bits nodig voor 40 °C: 632
# de range van de temperatuursensor is: -39 °C tot 89 °C

# %% [markdown]
# ## Boven 40 °C
# ![Alt](Opstelling_rood_18_2_2026.jpeg "meetopstelling rood")
# ## Tussen 30 °C en 40 °C
# ![Alt](Opstelling_geel_18_2_2026.jpeg "meetopstelling geel")
# ## Onder 30 °C
# ![Alt](Opstelling_groen_18_2_2026.jpeg "meetopstelling groen")

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Bruikbaarheid sensor gekozen toepassing:
# We hebben door middel van de meetpunten een verband kunnen bepalen tussen de temperatuur en de bits. Uit de functie fit bleek een lineair verband. Aan de hand van deze fit konden we +/- 1 graden Celsius nauwkeurig bepalen wat die bij die specifieke bits hoorde. Zo hebben we in de Arduino code verwerkt waardoor het lampje groene lampje onder de 30 graden Celsius ging branden, vanaf 30 tot 40 graden het gele lampje en boven de 40 graden ging het rode lampje branden. Je kunt de sensor dus gebruiken om te ongeveer te bepalen hoe warm iets is. Je weet echter alleen of het lager dan 30, tussen 30 en 40 of hoger dan 40 graden is.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# Om de Arduino zo te programmeren dat de LED's worden geactiveerd zodra de thermische sensor een bepaalde temperatuurgrens bereikt, moesten we een kleine RC-schakeling bouwen. Opdracht 5 laat zien dat wij een simpel circuit samen kunnen stellen met allerlei componenten zoals weerstanden, LED’s, temperatuur sensor, kabels etc.

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# Opdracht 2, toont aan de randvoorwaarde van de opdracht, de belangrijkste randvoorwaarde waren de temperatuurgrenzen, waarbij de LED kleur zou veranderen (30℃, 40℃). Ook toont opdracht 2 dat wij het SMART hadden opgesteld met duidelijke timeliness, specifieke bereikbare doelen.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# Dit is eigenlijk heel mooi door de hele python file verdeeld, ten eerste hadden wij bij opdracht 2 mooie toepassingen bedacht en goede criteria daarbij gevoegd om een kalibratie methode zo goed mogelijk te ontwerpen. De opstelling is duidelijk te zien in opdracht 5, en dan bij opdracht 6 waren alle meetresultaten verwerkt.
